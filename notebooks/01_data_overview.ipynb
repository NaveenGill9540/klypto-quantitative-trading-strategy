# %% [markdown]
# # Data Overview
#
# This notebook is used to understand the structure of the raw datasets used in the project.
#
# Due to API subscription limitations, historical NSE data is used and organized at a 5-minute frequency to simulate a real trading environment.
#
# The goal of this notebook is to inspect the data before applying any cleaning or feature engineering steps.

# %%
import pandas as pd

pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Expected Datasets
#
# The following datasets are used in this project:
#
# 1. NIFTY 50 Spot data (5-minute OHLCV)
# 2. NIFTY Futures data (current month contract)
# 3. NIFTY Options data (ATM Call and Put)
#
# Each dataset is aligned on timestamp to enable merging and feature creation.

# %% [markdown]
# # Data will be loaded in the next notebook after cleaning
